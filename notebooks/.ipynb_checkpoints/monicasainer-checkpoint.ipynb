# %% [markdown]
# # Greed and Fear Index

# %%
import requests

url = 'https://api.alternative.me/fng/'
params = {'limit':100000,'date_format':'world'}
response = requests.get(url,params).json()

# %%
import pandas as pd

# %%
table= pd.DataFrame(response['data'])

# %%
table.head()
# Out:
#   value value_classification   timestamp time_until_update
# 0    26                 Fear  05-12-2022       -1670160309
# 1    26                 Fear  04-12-2022               NaN
# 2    27                 Fear  03-12-2022               NaN
# 3    27                 Fear  02-12-2022               NaN
# 4    27                 Fear  01-12-2022               NaN

# %% [markdown]
# - Start date: 01-02-2018
# - Total obs: 1760

# %% [markdown]
# # Cryptocurrencies exchange rates

# %% [markdown]
# ## Cryptocurrencies (before 2018)

# %% [markdown]
# - Bitcoin (BTC) -2011
# - Ethereum (ETH) - 2016
# - Tether (USDT)- 2014
# - Binance coin (BNB)- 2017
# - Cardano (ADA) -2017
# - Ripple (XRP) - 2012
# - Dogecoin (DOGE) -2013
# - Monero (XMR) - 2014
# - Litecoin and Namecoin -2011
#
# Total:9

# %% [markdown]
# ❌ This library interacts with the [CoinBase Pro API](https://pypi.org/project/Historic-Crypto/)

# %%
! pip install Historic-Crypto
# Out:
# Requirement already satisfied: Historic-Crypto in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.1.6)
# Requirement already satisfied: numpy in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from Historic-Crypto) (1.23.4)
# Requirement already satisfied: requests in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from Historic-Crypto) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->Historic-Crypto) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->Historic-Crypto) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->Historic-Crypto) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/monic/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests->Historic-Crypto) (2022.9.24)

# %%
from Historic_Crypto import HistoricalData

# %%
new = HistoricalData('ETH-USD',86400,'2022-06-01-00-00','2022-06-01-00-03',verbose = False).retrieve_data()

# %%
new
# Out:
#                 low    high     open    close       volume
# time
# 2022-06-01  1761.59  1972.5  1940.49  1816.05  266690.7085

# %% [markdown]
# ## ✅ API Source: [CoinAPI](https://docs.coinapi.io/?python#http-requests)

# %% [markdown]
# ### Exchange rates

# %%
url = 'https://rest.coinapi.io/v1/exchangerate/BTC/USD/history?period_id=1DAY&time_start=2018-02-01T00:00:00&time_end=2022-12-02T00:00:00&limit=100000'
headers = {'X-CoinAPI-Key' : 'CC32A4FC-471F-4200-8788-6C980B2C8CAF'} #API-key
response = requests.get(url, headers=headers).json()

# %%
BTC_EUR=response
BTC_EUR=pd.DataFrame(BTC_EUR)
BTC_EUR.head()
# Out:
#               time_period_start               time_period_end  \
# 0  2018-02-01T00:00:00.0000000Z  2018-02-02T00:00:00.0000000Z
# 1  2018-02-02T00:00:00.0000000Z  2018-02-03T00:00:00.0000000Z
# 2  2018-02-03T00:00:00.0000000Z  2018-02-04T00:00:00.0000000Z
# 3  2018-02-04T00:00:00.0000000Z  2018-02-05T00:00:00.0000000Z
# 4  2018-02-05T00:00:00.0000000Z  2018-02-06T00:00:00.0000000Z
#
#                       time_open                    time_close    rate_open  \
# 0  2018-02-01T00:01:00.0000000Z  2018-02-01T23:59:00.0000000Z  8138.265304
# 1  2018-02-02T00:01:00.0000000Z  2018-02-02T23:59:00.0000000Z  7157.579687
# 2  2018-02-03T00:01:00.0000000Z  2018-02-03T23:59:00.0000000Z  7097.151833
# 3  2018-02-04T00:01:00.0000000Z  2018-02-04T23:59:00.0000000Z  7395.420831
# 4  2018-02-05T00:01:00.0000000Z  2018-02-05T23:59:00.0000000Z  6533.901159
#
#      rate_high     rate_low   rate_close
# 0  8211.111830  6679.270974  7173.216840
# 1  7394.836985  5828.259867  7106.972086
# 2  7666.302527  6528.501432  7419.294137
# 3  7600.537781  6227.691111  6505.891474
# 4  6768.299392  5099.020428  5466.568340

# %% [markdown]
# ❌ [alphavantage](https://www.alphavantage.co/documentation/#currency-daily)- Weird format

# %%
url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=EUR&apikey=VJECCG7TZAYBOPJ1'
r = requests.get(url)
data = r.json()
data=pd.DataFrame((data))
print(data)
# Out:
#                                                               Meta Data  \
# 1. Information            Daily Prices and Volumes for Digital Currency
# 2. Digital Currency Code                                            BTC
# 3. Digital Currency Name                                        Bitcoin
# 4. Market Code                                                      EUR
# 5. Market Name                                                     Euro
# ...                                                                 ...
# 2020-03-11                                                          NaN
# 2020-03-10                                                          NaN
# 2020-03-09                                                          NaN
# 2020-03-08                                                          NaN
# 2020-03-07                                                          NaN
#
#                                        Time Series (Digital Currency Daily)
# 1. Information                                                          NaN
# 2. Digital Currency Code                                                NaN
# 3. Digital Currency Name                                                NaN
# 4. Market Code                                                          NaN
# 5. Market Name                                                          NaN
# ...                                                                     ...
# 2020-03-11                {'1a. open (EUR)': '7566.15588800', '1b. open ...
# 2020-03-10                {'1a. open (EUR)': '7599.98740800', '1b. open ...
# 2020-03-09                {'1a. open (EUR)': '7700.51398400', '1b. open ...
# 2020-03-08                {'1a. open (EUR)': '8515.62360000', '1b. open ...
# 2020-03-07                {'1a. open (EUR)': '8751.04497600', '1b. open ...
#
# [1007 rows x 2 columns]

# %% [markdown]
# ### Exchange rates base asset identifier (market)

# %% [markdown]
# Documentation [here](https://docs.coinapi.io/#list-all-assets-get)

# %%
import requests
url = 'https://rest.coinapi.io/v1/assets'
headers = {'X-CoinAPI-Key' : 'CC32A4FC-471F-4200-8788-6C980B2C8CAF'} #API-key
response = requests.get(url, headers=headers).json()

# %%
response
market=[i['asset_id'] for i in response]

# %%
market #Example
# Out:
# ['USD',
#  'BTC',
#  'PLN',
#  'EUR',
#  'CNY',
#  'JPY',
#  'AUD',
#  'CHF',
#  'SEK',
#  'GBP',
#  'DKK',
#  'RUB',
#  'SGD',
#  'CAD',
#  'NZD',
#  'THB',
#  'NIS',
#  'LTC',
#  'KRW',
#  'VEN',
#  'XRP',
#  'NMC',
#  'USDT',
#  'DOGE',
#  'BLC',
#  'SLL',
#  'NVC',
#  'FTC',
#  'PPC',
#  'TRC',
#  'SVC',
#  'ORO',
#  'TOR',
#  'VEF',
#  'KST',
#  'BTS',
#  'NXT',
#  'BURST',
#  'PKR',
#  'SBC',
#  'BITCNY',
#  'DRK',
#  'DARK',
#  'U',
#  'BRL',
#  'CLP',
#  'ARI',
#  'MUE',
#  'SONG',
#  'CON',
#  'NAV',
#  'MCC',
#  'RICE',
#  'GEO',
#  'BITSD',
#  'QTL',
#  'TOP',
#  'RED',
#  'ETCO',
#  'NTC',
#  'AMBER',
#  'MTLMC',
#  'GUN',
#  'TIT',
#  'MCL',
#  'CRAVE',
#  'FONZ',
#  'SQL',
#  'DUCK',
#  'UNIC',
#  'OZC',
#  'LUX',
#  'BOB',
#  'AIB',
#  'ACP',
#  'BTX',
#  'DRZ',
#  'BSTY',
#  'LOG',
#  'DEM',
#  'CRW',
#  'SKC',
#  'FLN',
#  'ORB',
#  'LTS',
#  'MARS',
#  'UNO',
#  'SPN',
#  'PND',
#  'XVG',
#  'DGB',
#  'FUNK',
#  'XMG',
#  'CCB',
#  'SAK',
#  'XPD',
#  'AC',
#  '8BIT',
#  'XFC',
#  'ANI',
#  'TES',
#  'PLC',
#  'SHA',
#  'DUO',
#  '$PAC',
#  'MOTO',
#  'UNC',
#  'FJC',
#  'SJW',
#  'LEA',
#  'SOON',
#  'ADC',
#  'BNX',
#  'V',
#  'POLY',
#  'HYP',
#  'TTC',
#  'PIGGY',
#  'ICB',
#  'VGC',
#  'ELC',
#  'CTO',
#  'SPT',
#  'IEC',
#  'CFC',
#  'WDC',
#  'TEK',
#  'GDC',
#  'GBN',
#  'CRE',
#  'ETH',
#  'TRI',
#  'PR',
#  'RBY',
#  'EUC',
#  'GP',
#  'PAK',
#  'BLK',
#  'VRC',
#  'VND',
#  'CANN',
#  'CAPT',
#  'INFX',
#  'START',
#  'MEC',
#  'CLAM',
#  'ZEIT',
#  'XDC',
#  'RC',
#  'XPM',
#  'NET',
#  'GAIA',
#  'EMC',
#  'ISL',
#  'BOLI',
#  'BTCS',
#  'GCN',
#  'GLD',
#  'SLG',
#  'MBL',
#  'BTA',
#  'PTC',
#  'NOTE',
#  'BTCD',
#  'SMLY',
#  'WBB',
#  'PXC',
#  'EPC',
#  'BIRD',
#  'AUR',
#  'CESC',
#  'XMY',
#  'STV',
#  'CB',
#  'SXC',
#  'SHND',
#  'NKA',
#  'GRW',
#  'BTB',
#  'EGC',
#  'CV2',
#  'CORG',
#  'APC',
#  'TRK',
#  'EVO',
#  'BUCKS',
#  'XLM',
#  'GRC',
#  'CAP',
#  'MINT',
#  'RBT',
#  'BKCAT',
#  'EVIL',
#  'SHRM',
#  'ANTI',
#  'KLC',
#  'CDN',
#  'UIS',
#  'TX',
#  'BITB',
#  'BAC',
#  'FCT',
#  'EC',
#  'MOIN',
#  'UNB',
#  'BVC',
#  'ADCN',
#  'RBIES',
#  'QRK',
#  'XFT',
#  'BBR',
#  'KUMA',
#  'CBX',
#  'RPC',
#  'LTCR',
#  'KC',
#  'BIOS',
#  'EBG',
#  'REV',
#  'ZNY',
#  'FUZZ',
#  'IMS',
#  'BEEZ',
#  'LEAF',
#  'IXC',
#  'YOVI',
#  'ACOIN',
#  'RBBT',
#  'STS',
#  'DGD',
#  'FFC',
#  'BRG',
#  'NTRN',
#  'SIB',
#  'TRUMP',
#  'LIT',
#  'EDRC',
#  'BLZ',
#  'DASH',
#  'GMX',
#  'ARG',
#  'DAO',
#  'FUN',
#  'SC',
#  'SKR',
#  'DBIC',
#  'FRN',
#  'LSK',
#  'TGC',
#  'XCN',
#  'SYS',
#  'MAID',
#  'DIEM',
#  'XMR',
#  'DSH',
#  'RADS',
#  'DCR',
#  'BCN',
#  'EXP',
#  'SJCX',
#  'XCP',
#  'XVC',
#  'GEMZ',
#  'EXE',
#  'XEM',
#  'NAUT',
#  'RVR',
#  'VIA',
#  'USNBT',
#  'XDN',
#  'VTC',
#  'GAME',
#  'XCR',
#  'ADN',
#  'MYR',
#  'IOC',
#  '1CR',
#  'BITUSD',
#  'YACC',
#  'IFC',
#  'NEOS',
#  'QORA',
#  'RDD',
#  'FLO',
#  'AMP',
#  'CGA',
#  'LTBC',
#  'C2',
#  'XCH',
#  'RIC',
#  'BCY',
#  'PTS',
#  'CURE',
#  'XPB',
#  'HZ',
#  'SDC',
#  'XBCC',
#  'ARCH',
#  'POT',
#  'FLDC',
#  'EMC2',
#  'UNITY',
#  'MIL',
#  'GAP',
#  'MCN',
#  'NOXT',
#  'BELA',
#  'SILK',
#  'HUC',
#  'BTM',
#  'NSR',
#  'XC',
#  'BLOCK',
#  'XST',
#  'OMNI',
#  'INDEX',
#  'FLT',
#  'GRS',
#  'BITS',
#  'SYNC',
#  'XDP',
#  'NOBL',
#  'ABY',
#  'MMC',
#  'SWM',
#  'XUSD',
#  'LQD',
#  'PINK',
#  'FIBRE',
#  'QBK',
#  'CNMT',
#  'BERN',
#  'MMNXT',
#  'MNTA',
#  'CSC',
#  'XRA',
#  'CUBE',
#  'BXC',
#  'HAL',
#  'SWING',
#  'MNM',
#  'XTP',
#  'XCT',
#  'BAT',
#  'SMC',
#  'POP',
#  'CC',
#  'CHC',
#  'DRACO',
#  'TWO',
#  'KRB',
#  'YOC',
#  'NOC',
#  'LBC',
#  'QBTS',
#  'EL',
#  'LEO',
#  'CLOAK',
#  'STEEM',
#  'STEEMD',
#  'CJ',
#  '888',
#  'KDC',
#  'SYNX',
#  'ETC',
#  'XJO',
#  'LTB',
#  'COMET',
#  'ARPA',
#  'OTX',
#  'EDC',
#  'AU',
#  'WC',
#  'BAY',
#  'BOT',
#  'GRN',
#  'FIT',
#  'CST',
#  'BTG',
#  'CRX',
#  'VPRC',
#  'MAC',
#  'RAD',
#  'TWERK',
#  'ELE',
#  'JACK',
#  'TCX',
#  'SPEX',
#  'LDOGE',
#  'XAV',
#  'XAUR',
#  'POST',
#  'OPAL',
#  'DIME',
#  'FST',
#  'VAL',
#  'BENJI',
#  'KARMA',
#  'RCX',
#  'CRC',
#  'CF',
#  'ZEC',
#  'XHI',
#  'SPACE',
#  'ANS',
#  'FCH',
#  'WEX',
#  'TAO',
#  'VEC2',
#  'XPY',
#  'DXC',
#  'CHIP',
#  'KGC',
#  '404',
#  'CCN',
#  'XRE',
#  'REP',
#  'COAL',
#  'UMO',
#  'STRB',
#  'PSB',
#  'CAID',
#  'NEWB',
#  'RRT',
#  'XZC',
#  'NXE',
#  'ARDR',
#  'EMB',
#  'EMD',
#  'EFL',
#  'ROYAL',
#  'CNC',
#  'ARC',
#  'VEC',
#  'XID',
#  'HIFUN',
#  'PBC',
#  'HTML',
#  'WGC',
#  'PIVX',
#  'BVB',
#  'PHO',
#  'TCOIN',
#  'CBD',
#  'BIP',
#  'ZMC',
#  'ICN',
#  '1337',
#  'GNT',
#  'ANC',
#  'KOBO',
#  'MST',
#  'NETC',
#  'KURT',
#  'ARCO',
#  'FLVR',
#  'BOSON',
#  'HUSH',
#  'KIC',
#  'PNC',
#  'IW',
#  'ATOM',
#  'CURVES',
#  'ATX',
#  'INCP',
#  'SH',
#  'XCRE',
#  'POSW',
#  'DRKT',
#  'SFE',
#  'BTCU',
#  'STAR',
#  'NLG',
#  'VRS',
#  'JANE',
#  'DB',
#  'IN',
#  'PASC',
#  'STRAT',
#  'NXC',
#  'CIR',
#  'FAME',
#  'AEON',
#  'BST',
#  'GE',
#  'XAU',
#  'ZIRK',
#  'ZBC',
#  'LOOK',
#  'CHESS',
#  'C0C0',
#  'BTCRY',
#  'MCO',
#  'XTAG',
#  'DLC',
#  'RIN',
#  'PCC',
#  'MAD',
#  'TAG',
#  'CASH',
#  'NXS',
#  'GB',
#  'HCC',
#  'DDC',
#  'COV',
#  'GPU',
#  'RIO',
#  'CENT',
#  'DVC',
#  'TBC',
#  'DICE',
#  'TIPS',
#  'SRC',
#  'TOKEN',
#  'PULSE',
#  'MAX',
#  'DTC',
#  'ZET',
#  'SHELL',
#  'OK',
#  'TRADE',
#  'CMC',
#  'YAC',
#  'PSI',
#  'OMC',
#  'SEL',
#  'GHOST',
#  'BOOM',
#  'PXI',
#  'NYAN',
#  'DUB',
#  'BNB',
#  'DUST',
#  'CIRC',
#  'KTK',
#  'DBLK',
#  'PNK',
#  'STX',
#  'VTY',
#  'VIDZ',
#  'NANAS',
#  'ICOB',
#  'BURN',
#  'JIF',
#  'BASH',
#  'EPY',
#  'MARV',
#  'DON',
#  'STK',
#  'FTP',
#  'ESP',
#  'XBY',
#  'SCRT',
#  'MOOND',
#  'LC',
#  'BIC',
#  'UNIT',
#  'BEEP',
#  'DC',
#  'SUPER',
#  'MSC',
#  'CKS',
#  'TIX',
#  'TEAM',
#  'BUB',
#  'DBG',
#  'BIGUP',
#  'BSH',
#  'CLINT',
#  'ZOOM',
#  'GML',
#  'ZCC',
#  'LANA',
#  'DECR',
#  'NEVA',
#  'VTN',
#  'ACID',
#  'TAB',
#  'SLFI',
#  'NEC',
#  'MYSTIC',
#  'TIA',
#  'TOOL',
#  'TENNET',
#  'CYC',
#  'EKO',
#  'XBTS',
#  'UB',
#  'P7C',
#  'ILM',
#  'TAJ',
#  'BS',
#  'NODE',
#  'NPC',
#  'EXB',
#  'YBC',
#  'IBITS',
#  'SHREK',
#  'PINKX',
#  'RING',
#  'SCITW',
#  'DOV',
#  'CZECO',
#  'TAGR',
#  'RUST',
#  'HIRE',
#  'WRC',
#  'NUM',
#  'BRDD',
#  'KUBO',
#  'GTFO',
#  'B3',
#  'EURC',
#  'SFC',
#  'MARX',
#  'BTCR',
#  'EQUAL',
#  'STA',
#  'TRANSF',
#  'CPC',
#  'YAY',
#  'DGORE',
#  'MPRO',
#  'COX',
#  'CYG',
#  'DGMS',
#  'NEBU',
#  'GREXIT',
#  'LOC',
#  'AECC',
#  'ASAFE',
#  'SMBR',
#  'COIN',
#  'VTX',
#  'ENE',
#  'LUCKY',
#  'TERA',
#  'GSX',
#  'GIFT',
#  'XBTC21',
#  'DGCS',
#  'ZLQ',
#  'RNC',
#  'DKC',
#  'STC',
#  'ZECD',
#  'GENIUS',
#  'PEN',
#  'LEPEN',
#  'STRP',
#  'SDG',
#  'SOLO',
#  'CCX',
#  'SLING',
#  'KMD',
#  'GENE',
#  'ACPR',
#  '32BIT',
#  'MIS',
#  'BOMB',
#  'LSD',
#  'BON',
#  'JPC',
#  'GRAV',
#  'SPEC',
#  'ELS',
#  'TSE',
#  'PLANET',
#  'UNITS',
#  'MDT',
#  'TRA',
#  'CRIME',
#  'DLISK',
#  'SPM',
#  'POKE',
#  'DPAY',
#  'DFT',
#  'METAL',
#  'FCASH',
#  'XCO',
#  'TRON',
#  'CYT',
#  'SSC',
#  'TUR',
#  'GMCX',
#  'RICHX',
#  'TNG',
#  'OP',
#  'SOUL',
#  'NAT',
#  'NBIT',
#  'GOAT',
#  'WBTC',
#  'TOT',
#  'BDC',
#  'CTL',
#  'XT',
#  'SIX',
#  'OBS',
#  'GEN',
#  'SCASH',
#  'BTZ',
#  'AIR',
#  'BTCO',
#  'TRAP',
#  'DGC',
#  'VTL',
#  'ARM',
#  'ARB',
#  'FRWC',
#  'EGO',
#  'PAL',
#  'JWL',
#  'XPC',
#  'WINE',
#  'WAY',
#  'BCOIN',
#  'GSY',
#  'NODC',
#  'OCOW',
#  'UNF',
#  'SANDG',
#  'TAK',
#  'ALTC',
#  'CRPS',
#  'WAVES',
#  'JW',
#  'DROP',
#  'IMPS',
#  'CARBON',
#  'SWEET',
#  'M1',
#  'SMF',
#  'HXX',
#  'AUM',
#  'MRB',
#  'XDB',
#  'FLX',
#  'VPN',
#  '007',
#  'HZT',
#  'GIZ',
#  'RMS',
#  'FLY',
#  'PRE',
#  'IBANK',
#  'IVZ',
#  'DCC',
#  'POWER',
#  'PXL',
#  'XMT',
#  'BA',
#  'DOT',
#  'APT',
#  'HEDG',
#  'SUB',
#  'NDOGE',
#  'UTC',
#  'URC',
#  'XSSX',
#  'RIDE',
#  'TFC',
#  'SPX',
#  'DOX',
#  'XDE2',
#  'GHS',
#  'DCK',
#  'XOT',
#  'EGG',
#  'INV',
#  'XMS',
#  'NKT',
#  'DISK',
#  'HVCO',
#  'DCRE',
#  'SP',
#  'SCAN',
#  'ETHS',
#  'JOK',
#  'FOREX',
#  'ENTER',
#  'SCRPT',
#  'URO',
#  'PONZ2',
#  'MCRN',
#  'DCT',
#  'ALC',
#  'CORAL',
#  'TALK',
#  'MM',
#  'PARA',
#  'PCM',
#  'STP',
#  'ALEX',
#  'HTC',
#  'TELL',
#  'ECC',
#  'MAR',
#  'DTT',
#  '2GIVE',
#  'HSP',
#  'TB',
#  'DIRT',
#  'ACLR',
#  'KUSH',
#  'ZNE',
#  'LUN',
#  'ENG',
#  'BOD',
#  'PIE',
#  'GAKH',
#  'BPOK',
#  'AST',
#  'CTK',
#  'ICON',
#  'PEO',
#  'FIRE',
#  'SPR',
#  'ARTC',
#  'CS',
#  'SPORT',
#  'CLUB',
#  'CG',
#  'QBC',
#  'VENE',
#  'LIV',
#  'QTZ',
#  'OPES',
#  'RADI',
#  'MRP',
#  'WARP',
#  'MXT',
#  'MMXVI',
#  'RISE',
#  'NIC',
#  'BTDX',
#  'DRM',
#  'CME',
#  'OLYMP',
#  'GBIT',
#  'VEG',
#  'LIR',
#  'X2',
#  'TIC',
#  'BLRY',
#  'BBCC',
#  'MND',
#  'GOTX',
#  'TCR',
#  'ESC',
#  'COXST',
#  'SIGU',
#  'EXT',
#  'LKC',
#  'CRNK',
#  'MONETA',
#  'MOON',
#  'BITON',
#  'MONA',
#  'VOL',
#  'CLICK',
#  'BLUS',
#  'XOC',
#  'ZUR',
#  'VCOIN',
#  'BSTAR',
#  'LVG',
#  'PAY',
#  'GIG',
#  'SSTC',
#  'HAZE',
#  'NYC',
#  'RSS',
#  'XMINE',
#  'PX',
#  'EOC',
#  'CHOOF',
#  'ICASH',
#  'ZER',
#  'PIO',
#  'ARGUS',
#  'TKN',
#  'FRE',
#  'ZET2',
#  'PWR',
#  'SED',
#  'XNX',
#  'LGBTQ',
#  'GCR',
#  'CLUD',
#  'XNC',
#  'EMP',
#  'FADE',
#  'HEEL',
#  'CSMIC',
#  'PLNC',
#  'TEC',
#  'OS76',
#  'XBU',
#  'GLUCK',
#  'XCE',
#  'GRE',
#  'SKB',
#  'XQN',
#  'PONZI',
#  'NICE',
#  'RATIO',
#  'ACES',
#  'MLITE',
#  'VOYA',
#  'L7S',
#  'WMC',
#  'BSTK',
#  'CAR',
#  'TWIST',
#  'ASN',
#  'NLC2',
#  'DCYP',
#  'GBT',
#  'ORLY',
#  'LTH',
#  'BAM',
#  'ARE',
#  'PKB',
#  'UAE',
#  'BRAIN',
#  'TRICK',
#  'HODL',
#  'STHR',
#  'FRK',
#  'N2O',
#  'JOBS',
#  'EMPC',
#  'PTY',
#  'COC',
#  'CRAB',
#  'CHRG',
#  'CYP',
#  'GCC',
#  'BIT16',
#  'SHORTY',
#  'TP1',
#  'VISIO',
#  'GUM',
#  'PHR',
#  'ATM',
#  'MONEY',
#  'TECH',
#  'SLS',
#  'SRND',
#  'MAPC',
#  'XPRO',
#  'EAGS',
#  'KAT',
#  'VAPOR',
#  'N7',
#  'BHC',
#  'MTC',
#  'ECLI',
#  'PAYP',
#  'FRDC',
#  'AMS',
#  'RONIN',
#  'NIXON',
#  'ENT',
#  'GOON',
#  'XSP',
#  'BTP',
#  'CRY',
#  'DES',
#  '2015',
#  'STO',
#  'GREED',
#  'REE',
#  'ETRUST',
#  'TAM',
#  'XFCX',
#  'RBIT',
#  'TDFB',
#  'KRAK',
#  'CHEMX',
#  'YTC',
#  'TPG',
#  'XSY',
#  'XPO',
#  '2BACCO',
#  'LOOT',
#  'PRM',
#  'MAZE',
#  'SIC',
#  'NRC',
#  'AM',
#  'DOGETH',
#  'XDE',
#  'LAZ',
#  'STEPS',
#  'KR',
#  'BPC',
#  'NETKO',
#  'NUKE',
#  ...]

# %%
len(market)
# Out:
# 16378

# %%
type(BTC_EUR)
# Out:
# pandas.core.frame.DataFrame

# %%
import seaborn as sns
sns.scatterplot(table['value'],BTC_EUR['rate_close'].head(100))
# Out:
# /Users/monic/.pyenv/versions/lewagon/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='value', ylabel='rate_close'>

# %% [markdown]
# ### Optional: Add graphs with the current quotes for the exchanges with the selected cryptocurrency : idea [here](https://lewagon-alumni.slack.com/archives/D048CNCG5C2/p1669393053148439)
